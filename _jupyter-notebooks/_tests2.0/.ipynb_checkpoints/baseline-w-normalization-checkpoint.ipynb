# %% [markdown]
# ## Baseline w Normalization

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import shutil
import os 
import glob
import csv
import json
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as confusion_matrix_sklearn

from ketos.data_handling import selection_table as sl
import ketos.data_handling.database_interface as dbi
from ketos.data_handling.parsing import load_audio_representation
from ketos.data_handling.data_feeding import BatchGenerator
from ketos.neural_networks.resnet import ResNetInterface
from ketos.audio.audio_loader import AudioFrameLoader, AudioLoader, SelectionTableIterator
from ketos.audio.spectrogram import MagSpectrogram
from ketos.neural_networks.dev_utils.detection import batch_load_audio_file_data, filter_by_threshold, filter_by_label, merge_overlapping_detections
from ketos.data_handling.data_feeding import JointBatchGen

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

print('done importing packages')
# Out:
# done importing packages

# %% [markdown]
# ## Train Models

# %% [markdown]
# ### Mean 0, Std 1.0

# %%
main_folder = r'E:\baseline-w-normalization'
spectro_file = main_folder + '\\' + 'spec_config_100-1200Hz-0.032-hamm-normalized0.json'
recipe_file = r'E:\final-baseline-detector\resnet_recipe-1.json'
pos_folder = r'E:\final-baseline-detector\annots\pos'
neg_folder = r'E:\final-baseline-detector\annots\neg'
file_durations_file = r'E:\final-baseline-detector\all_file_durations_complete.xlsx'
file_durations = pd.read_excel(file_durations_file)

db_name = main_folder + '\\' + 'final-baseline-db-normalized0.h5'
model_name = main_folder + '\\' + 'final-baseline-model-normalized0.kt'
temp_folder = main_folder + '\\' + 'rs-temp'

data_folder = r'D:\ringed-seal-data'

# %%
# Get list of all csv files in positives annot folder 
files_pos = glob.glob(pos_folder + "/*.csv")

site_names = []
num_annots = []

# For each csv file
for file in files_pos:

    annots = pd.read_csv(file)

    site_name = file.split('\\')[-1].split('.')[0].split('_')[0]

    site_names.append(site_name)
    num_annots.append(len(annots))

ULU22_val = num_annots[site_names.index('ULU2022')]
other_val = sum(num_annots) - ULU22_val
all_annots = sum(num_annots)

ulu_2022_split = 0.32
all_else_split = 1 - ulu_2022_split

dataset_split = [0.7, 0.2, 0.1]

train_annots = round(all_annots*dataset_split[0])
val_annots = round(all_annots*dataset_split[1])
test_annots = round(all_annots*dataset_split[2])

# ulu22 vals
ulu22_tr = round(train_annots*ulu_2022_split)
ulu22_va = round(val_annots*ulu_2022_split)
ulu22_te = round(test_annots*ulu_2022_split)

ulu22_leftovers = ULU22_val - ulu22_tr - ulu22_va - ulu22_te

if ulu22_leftovers < 0:
    ulu22_te = ulu22_te + ulu22_leftovers

if ulu22_leftovers > 0 :
    ulu22_tr = ulu22_tr + ulu22_leftovers

all_ulu = ulu22_tr + ulu22_te + ulu22_va

if all_ulu != ULU22_val:
    print('Something went wrong with Ulu')
    exit()

ulu2022_vals = [ulu22_tr, ulu22_va, ulu22_te]

# rest vals
rest_tr = round(train_annots*all_else_split)
rest_va = round(val_annots*all_else_split)
rest_te = round(test_annots*all_else_split)

# totals
all_added = rest_tr + rest_va + rest_te

if all_added < other_val:
    leftover = other_val - all_added
    rest_tr = rest_tr + leftover

if all_added > other_val:
    leftover = all_added - other_val
    rest_va = rest_va - leftover

all_added2 = rest_tr + rest_va + rest_te

cb_perc = num_annots[0]/all_added2
kk_perc = num_annots[1]/all_added2
ulu_perc = num_annots[4]/all_added2

# split into other site vals
cb_tr = round(cb_perc*rest_tr)
cb_va = round(cb_perc*rest_va)
cb_te = round(cb_perc*rest_te)
total_cb = cb_tr + cb_va + cb_te
if total_cb < num_annots[0]:
    leftover_cb = num_annots[0] - total_cb
    cb_tr = cb_tr + leftover_cb
if total_cb > num_annots[0]:
    leftover_cb = num_annots[0] - total_cb
    cb_va = cb_va + leftover_cb
cb_vals = [cb_tr, cb_va, cb_te]

kk_tr = round(kk_perc*rest_tr)
kk_va = round(kk_perc*rest_va)
kk_te = round(kk_perc*rest_te)
total_kk = kk_tr + kk_va + kk_te
if total_kk < num_annots[1]:
    leftover_kk = num_annots[1] - total_kk
    kk_tr = kk_tr + leftover_kk
if total_kk > num_annots[1]:
    leftover_kk = num_annots[1] - total_kk
    kk_va = kk_va + leftover_kk
kk_vals = [kk_tr, kk_va, kk_te]
    
ulu_tr = round(ulu_perc*rest_tr)
ulu_va = round(ulu_perc*rest_va)
ulu_te = round(ulu_perc*rest_te)
total_ulu = ulu_tr + ulu_va + ulu_te
if total_ulu < num_annots[4]:
    leftover_ulu = num_annots[4] - total_ulu
    ulu_tr = ulu_tr + leftover_ulu
if total_ulu > num_annots[4]:
    leftover_ulu = num_annots[4] - total_ulu
    ulu_va = ulu_va + leftover_ulu
ulu_vals = [ulu_tr, ulu_va, ulu_te]

print('ulu22 vals (tr, va, te): ' + str(ulu2022_vals) + ', total: ' + str(sum(ulu2022_vals)))
print('ulu vals (tr, va, te): ' + str(ulu_vals) + ', total: ' + str(sum(ulu_vals)))
print('kk vals (tr, va, te): ' + str(kk_vals) + ', total: ' + str(sum(kk_vals)))
print('cb vals (tr, va, te): ' + str(cb_vals) + ', total: ' + str(sum(cb_vals)))
# Out:
# ulu22 vals (tr, va, te): [1037, 296, 143], total: 1476
# ulu vals (tr, va, te): [669, 191, 95], total: 955
# kk vals (tr, va, te): [1348, 384, 192], total: 1924
# cb vals (tr, va, te): [133, 38, 19], total: 190

# %%
## Create Database ##

# negatives tables and standarize for ketos
ulu_neg = pd.read_excel(neg_folder + '\\' + 'ULU-negs-joined.xlsx')
ulu_neg = ulu_neg.ffill()
ulu_neg = sl.standardize(table=ulu_neg)
print('Negatives standardized? ' + str(sl.is_standardized(ulu_neg)))

ulu2022_neg = pd.read_excel(neg_folder + '\\' + 'ULU2022-negs-joined.xlsx')
ulu2022_neg = ulu2022_neg.ffill()
ulu2022_neg = sl.standardize(table=ulu2022_neg)
print('Negatives standardized? ' + str(sl.is_standardized(ulu2022_neg)))

kk_neg = pd.read_excel(neg_folder + '\\' + 'KK-negs-joined.xlsx')
kk_neg = kk_neg.ffill()
kk_neg = sl.standardize(table=kk_neg)
print('Negatives standardized? ' + str(sl.is_standardized(kk_neg)))

cb_neg = pd.read_excel(neg_folder + '\\' + 'CB-negs-joined.xlsx')
cb_neg = cb_neg.ffill()
cb_neg = sl.standardize(table=cb_neg)
print('Negatives standardized? ' + str(sl.is_standardized(cb_neg)))

# positives tables
ulu_pos = pd.read_csv(pos_folder + '\\' + 'ULU_all_formatted_1sec.csv')
ulu_pos = ulu_pos.ffill()
ulu_pos = sl.standardize(table=ulu_pos, start_labels_at_1=True)
print('Positives standardized? ' + str(sl.is_standardized(ulu_pos)))

ulu2022_pos = pd.read_csv(pos_folder + '\\' + 'ULU2022_all_formatted_1sec.csv')
ulu2022_pos = ulu2022_pos.ffill()
ulu2022_pos = sl.standardize(table=ulu2022_pos, start_labels_at_1=True)
print('Positives standardized? ' + str(sl.is_standardized(ulu2022_pos)))

kk_pos = pd.read_csv(pos_folder + '\\' + 'KK_all_formatted_1sec.csv')
kk_pos = kk_pos.ffill()
kk_pos = sl.standardize(table=kk_pos, start_labels_at_1=True)
print('Positives standardized? ' + str(sl.is_standardized(kk_pos)))

cb_pos = pd.read_csv(pos_folder + '\\' + 'CB_all_formatted_1sec.csv')
cb_pos = cb_pos.ffill()
cb_pos = sl.standardize(table=cb_pos, start_labels_at_1=True)
print('Positives standardized? ' + str(sl.is_standardized(cb_pos)))

# join into complete tables

ulu_pos_tr = ulu_pos.head(ulu_vals[0])
ulu_pos_va = ulu_pos[ulu_vals[0]:ulu_vals[0] + ulu_vals[1]]
ulu_pos_te = ulu_pos.tail(ulu_vals[2])

ulu_neg_tr = ulu_neg.head(ulu_vals[0])
ulu_neg_va = ulu_neg[ulu_vals[0]:ulu_vals[0] + ulu_vals[1]]
ulu_neg_te = ulu_neg.tail(ulu_vals[2])

ulu_tr = pd.concat([ulu_pos_tr, ulu_neg_tr])
ulu_va = pd.concat([ulu_pos_va, ulu_neg_va])
ulu_te = pd.concat([ulu_pos_te, ulu_neg_te])

ulu2022_pos_tr = ulu2022_pos.head(ulu2022_vals[0])
ulu2022_pos_va = ulu2022_pos[ulu2022_vals[0]:ulu2022_vals[0] + ulu2022_vals[1]]
ulu2022_pos_te = ulu2022_pos.tail(ulu2022_vals[2])

ulu2022_neg_tr = ulu2022_neg.head(ulu2022_vals[0])
ulu2022_neg_va = ulu2022_neg[ulu2022_vals[0]:ulu2022_vals[0] + ulu2022_vals[1]]
ulu2022_neg_te = ulu2022_neg.tail(ulu2022_vals[2])

ulu2022_tr = pd.concat([ulu2022_pos_tr, ulu2022_neg_tr])
ulu2022_va = pd.concat([ulu2022_pos_va, ulu2022_neg_va])
ulu2022_te = pd.concat([ulu2022_pos_te, ulu2022_neg_te])

kk_pos_tr = kk_pos.head(kk_vals[0])
kk_pos_va = kk_pos[kk_vals[0]:kk_vals[0] + kk_vals[1]]
kk_pos_te = kk_pos.tail(kk_vals[2])

kk_neg_tr = kk_neg.head(kk_vals[0])
kk_neg_va = kk_neg[kk_vals[0]:kk_vals[0] + kk_vals[1]]
kk_neg_te = kk_neg.tail(kk_vals[2])

kk_tr = pd.concat([kk_pos_tr, kk_neg_tr])
kk_va = pd.concat([kk_pos_va, kk_neg_va])
kk_te = pd.concat([kk_pos_te, kk_neg_te])

cb_pos_tr = cb_pos.head(cb_vals[0])
cb_pos_va = cb_pos[cb_vals[0]:cb_vals[0] + cb_vals[1]]
cb_pos_te = cb_pos.tail(cb_vals[2])

cb_neg_tr = cb_neg.head(cb_vals[0])
cb_neg_va = cb_neg[cb_vals[0]:cb_vals[0] + cb_vals[1]]
cb_neg_te = cb_neg.tail(cb_vals[2])

cb_tr = pd.concat([cb_pos_tr, cb_neg_tr])
cb_va = pd.concat([cb_pos_va, cb_neg_va])
cb_te = pd.concat([cb_pos_te, cb_neg_te])

# final three tables

train = pd.concat([ulu_tr, ulu2022_tr, cb_tr, kk_tr])
val = pd.concat([ulu_va, ulu2022_va, cb_va, kk_va])
test = pd.concat([ulu_te, ulu2022_te, cb_te, kk_te])
# Out:
# Negatives standardized? True
# Negatives standardized? True
# Negatives standardized? True
# Negatives standardized? True
# Positives standardized? True
# Positives standardized? True
# Positives standardized? True
# Positives standardized? True

# %%
def drop_rows(file_durations, table):

    drop = []

    print('cleaning training table of original length ' + str(len(table)))

    for idex, row in table.iterrows():
    
        # filename is row[0], end time is idex.end
        index = file_durations.loc[file_durations['filename'] == row.name[0]].index
        duration = file_durations['duration'][index].values[0]
    
        if duration < row.end:
            # drop the row corresponding to that sel_id and filename from the dataframe
            drop.append(idex)
    
        if row.start < 0:
            drop.append(idex)
    
    print('Number of rows to drop (note, one entry may be in list twice): ' + str(len(drop)))

    return drop

# %%
drop_rows_tr = drop_rows(file_durations, train)
train = train.drop(drop_rows_tr)
train.to_csv(main_folder + '\\' + 'train.csv', index=False)
print(len(train))
drop_rows_va = drop_rows(file_durations, val)
val = val.drop(drop_rows_va)
print(len(val))
drop_rows_te = drop_rows(file_durations, test)
test = test.drop(drop_rows_te)
print(len(test))
# Out:
# cleaning training table of original length 6374
# Number of rows to drop (note, one entry may be in list twice): 10
# 6362
# cleaning training table of original length 1818
# Number of rows to drop (note, one entry may be in list twice): 4
# 1813
# cleaning training table of original length 898
# Number of rows to drop (note, one entry may be in list twice): 2
# 894

# %%
train.to_csv(main_folder + '\\' + 'train.csv')
val.to_csv(main_folder + '\\' + 'val.csv')
test.to_csv(main_folder + '\\' + 'test.csv')

# %%
# join into a database
# Load the spectrogram representation & parameters, this returns a dict 
spec_cfg = load_audio_representation(spectro_file, name="spectrogram")

# %%
# Create a table called "train" in the database, defined by db_name, using the "train" selections table, the spectrogram config, and the audio data 
# Behind the hood, this creates an AudioLoader and AudioWriter Ketos function which generates the spectrograms for each selection 
dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'train', selections=train, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'val', selections=val, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'test', selections=test, data_dir=data_folder,
                    audio_repres=spec_cfg)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6362/6362 [03:01<00:00, 35.11it/s]
# 6362 items saved to E:\baseline-w-normalization\final-baseline-db-normalized0.h5
# 100%|██████████████████████████████████████████████████████████████████████████████| 1813/1813 [00:45<00:00, 39.88it/s]
# 1813 items saved to E:\baseline-w-normalization\final-baseline-db-normalized0.h5
# 100%|████████████████████████████████████████████████████████████████████████████████| 894/894 [00:22<00:00, 39.06it/s]
# 894 items saved to E:\baseline-w-normalization\final-baseline-db-normalized0.h5

# %%
# Set the random seed for numpy and tensorflow 
np.random.seed(1000)
tf.random.set_seed(2000)

# Set the batch size and number of epochs for training
batch_size = 16
n_epochs = 40

# Set the log folder and checkpoint folder 
log_folder = main_folder + '\\' + 'logs-normalize0'
checkpoint_folder = main_folder + '\\' + 'checkpoints-normalize0'

# Open the database file in read mode
db = dbi.open_file(db_name, 'r')

# Open the training and validation tables respectively 
train_data = dbi.open_table(db, "/train/data")
val_data = dbi.open_table(db, "/val/data")

# Create batches of training data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
train_generator = BatchGenerator(batch_size=batch_size, data_table=train_data,
                                    output_transform_func=ResNetInterface.transform_batch,
                                    shuffle=True, refresh_on_epoch_end=True)

# Create batches of validation data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
val_generator = BatchGenerator(batch_size=batch_size, data_table=val_data,
                                   output_transform_func=ResNetInterface.transform_batch,
                                   shuffle=False, refresh_on_epoch_end=False)

# Build the ResNet model file based off of the recipe file - this creates a "ResNetInterface" object 
resnet = ResNetInterface.build(recipe_file)

# Set the training and validation generators to the batch generators created above 
resnet.train_generator = train_generator
resnet.val_generator = val_generator

# Set the model log and checkpoint directory 
resnet.log_dir = log_folder
resnet.checkpoint_dir = checkpoint_folder

# Train the model, looping through all of the training and validation data 
# See code map for more information
resnet.train_loop(n_epochs=n_epochs, verbose=True, log_csv=True, csv_name='log-hamm-0.32-manual.csv')

# Close the database 
db.close()

# Save the model file, and keep track of the spectrogram parameters used to generate that model 
resnet.save(model_name, audio_repr_file=spectro_file)

print('Done')
# Out:
# ====================================================================================
# Epoch: 1
# train_loss: 0.24031352996826172
# train_CategoricalAccuracy: 0.801 train_Precision: 0.843 train_Recall: 0.740
# val_loss: 0.2771132290363312
# val_CategoricalAccuracy: 0.727 val_Precision: 0.839 val_Recall: 0.560
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 2
# train_loss: 0.1663227379322052
# train_CategoricalAccuracy: 0.868 train_Precision: 0.884 train_Recall: 0.848
# val_loss: 0.1877216100692749
# val_CategoricalAccuracy: 0.851 val_Precision: 0.864 val_Recall: 0.832
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 3
# train_loss: 0.14193488657474518
# train_CategoricalAccuracy: 0.887 train_Precision: 0.900 train_Recall: 0.869
# val_loss: 0.17445001006126404
# val_CategoricalAccuracy: 0.870 val_Precision: 0.885 val_Recall: 0.850
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 4
# train_loss: 0.13305558264255524
# train_CategoricalAccuracy: 0.892 train_Precision: 0.902 train_Recall: 0.879
# val_loss: 0.1454048603773117
# val_CategoricalAccuracy: 0.887 val_Precision: 0.876 val_Recall: 0.903
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 5
# train_loss: 0.12387711554765701
# train_CategoricalAccuracy: 0.903 train_Precision: 0.913 train_Recall: 0.891
# val_loss: 0.14476631581783295
# val_CategoricalAccuracy: 0.874 val_Precision: 0.895 val_Recall: 0.846
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 6
# train_loss: 0.12151604890823364
# train_CategoricalAccuracy: 0.903 train_Precision: 0.912 train_Recall: 0.892
# val_loss: 0.16315217316150665
# val_CategoricalAccuracy: 0.864 val_Precision: 0.883 val_Recall: 0.838
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 7
# train_loss: 0.11598260700702667
# train_CategoricalAccuracy: 0.908 train_Precision: 0.911 train_Recall: 0.903
# val_loss: 0.16087564826011658
# val_CategoricalAccuracy: 0.860 val_Precision: 0.902 val_Recall: 0.808
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 8
# train_loss: 0.11334743350744247
# train_CategoricalAccuracy: 0.912 train_Precision: 0.914 train_Recall: 0.908
# val_loss: 0.1566527783870697
# val_CategoricalAccuracy: 0.879 val_Precision: 0.901 val_Recall: 0.852
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 9
# train_loss: 0.10585328191518784
# train_CategoricalAccuracy: 0.916 train_Precision: 0.917 train_Recall: 0.914
# val_loss: 0.14981141686439514
# val_CategoricalAccuracy: 0.871 val_Precision: 0.891 val_Recall: 0.844
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 10
# train_loss: 0.1054445281624794
# train_CategoricalAccuracy: 0.916 train_Precision: 0.920 train_Recall: 0.911
# val_loss: 0.13832150399684906
# val_CategoricalAccuracy: 0.878 val_Precision: 0.894 val_Recall: 0.857
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 11
# train_loss: 0.1050458699464798
# train_CategoricalAccuracy: 0.919 train_Precision: 0.921 train_Recall: 0.916
# val_loss: 0.15095756947994232
# val_CategoricalAccuracy: 0.873 val_Precision: 0.905 val_Recall: 0.833
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 12
# train_loss: 0.10073298215866089
# train_CategoricalAccuracy: 0.923 train_Precision: 0.925 train_Recall: 0.920
# val_loss: 0.12926657497882843
# val_CategoricalAccuracy: 0.889 val_Precision: 0.871 val_Recall: 0.913
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 13
# train_loss: 0.10097832977771759
# train_CategoricalAccuracy: 0.920 train_Precision: 0.924 train_Recall: 0.916
# val_loss: 0.12779304385185242
# val_CategoricalAccuracy: 0.900 val_Precision: 0.872 val_Recall: 0.937
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 14
# train_loss: 0.0957685261964798
# train_CategoricalAccuracy: 0.926 train_Precision: 0.921 train_Recall: 0.933
# val_loss: 0.14502820372581482
# val_CategoricalAccuracy: 0.876 val_Precision: 0.901 val_Recall: 0.845
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 15
# train_loss: 0.09532480686903
# train_CategoricalAccuracy: 0.926 train_Precision: 0.927 train_Recall: 0.924
# val_loss: 0.13243703544139862
# val_CategoricalAccuracy: 0.901 val_Precision: 0.890 val_Recall: 0.914
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 16
# train_loss: 0.09310054779052734
# train_CategoricalAccuracy: 0.927 train_Precision: 0.924 train_Recall: 0.931
# val_loss: 0.12220512330532074
# val_CategoricalAccuracy: 0.906 val_Precision: 0.886 val_Recall: 0.931
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 17
# train_loss: 0.09298783540725708
# train_CategoricalAccuracy: 0.928 train_Precision: 0.923 train_Recall: 0.934
# val_loss: 0.15984535217285156
# val_CategoricalAccuracy: 0.865 val_Precision: 0.912 val_Recall: 0.809
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 18
# train_loss: 0.09088358283042908
# train_CategoricalAccuracy: 0.930 train_Precision: 0.928 train_Recall: 0.933
# val_loss: 0.12119566649198532
# val_CategoricalAccuracy: 0.905 val_Precision: 0.889 val_Recall: 0.926
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 19
# train_loss: 0.08907313644886017
# train_CategoricalAccuracy: 0.934 train_Precision: 0.934 train_Recall: 0.933
# val_loss: 0.12376449257135391
# val_CategoricalAccuracy: 0.899 val_Precision: 0.879 val_Recall: 0.924
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 20
# train_loss: 0.0892268717288971
# train_CategoricalAccuracy: 0.932 train_Precision: 0.931 train_Recall: 0.933
# val_loss: 0.1272944062948227
# val_CategoricalAccuracy: 0.897 val_Precision: 0.896 val_Recall: 0.898
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 21
# train_loss: 0.08640499413013458
# train_CategoricalAccuracy: 0.934 train_Precision: 0.936 train_Recall: 0.933
# val_loss: 0.1283225268125534
# val_CategoricalAccuracy: 0.896 val_Precision: 0.889 val_Recall: 0.905
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 22
# train_loss: 0.08507078886032104
# train_CategoricalAccuracy: 0.937 train_Precision: 0.936 train_Recall: 0.938
# val_loss: 0.13383124768733978
# val_CategoricalAccuracy: 0.889 val_Precision: 0.896 val_Recall: 0.880
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 23
# train_loss: 0.08670283854007721
# train_CategoricalAccuracy: 0.933 train_Precision: 0.932 train_Recall: 0.933
# val_loss: 0.13423806428909302
# val_CategoricalAccuracy: 0.891 val_Precision: 0.907 val_Recall: 0.871
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 24
# train_loss: 0.08574870973825455
# train_CategoricalAccuracy: 0.935 train_Precision: 0.933 train_Recall: 0.936
# val_loss: 0.12330754846334457
# val_CategoricalAccuracy: 0.897 val_Precision: 0.894 val_Recall: 0.902
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 25
# train_loss: 0.0855574905872345
# train_CategoricalAccuracy: 0.936 train_Precision: 0.934 train_Recall: 0.938
# val_loss: 0.1285703331232071
# val_CategoricalAccuracy: 0.895 val_Precision: 0.898 val_Recall: 0.892
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 26
# train_loss: 0.08397684246301651
# train_CategoricalAccuracy: 0.937 train_Precision: 0.938 train_Recall: 0.937
# val_loss: 0.12551727890968323
# val_CategoricalAccuracy: 0.897 val_Precision: 0.892 val_Recall: 0.904
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 27
# train_loss: 0.08207836002111435
# train_CategoricalAccuracy: 0.938 train_Precision: 0.940 train_Recall: 0.936
# val_loss: 0.12478306144475937
# val_CategoricalAccuracy: 0.899 val_Precision: 0.895 val_Recall: 0.903
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 28
# train_loss: 0.07781631499528885
# train_CategoricalAccuracy: 0.943 train_Precision: 0.942 train_Recall: 0.944
# val_loss: 0.12716522812843323
# val_CategoricalAccuracy: 0.897 val_Precision: 0.896 val_Recall: 0.897
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 29
# train_loss: 0.07993566989898682
# train_CategoricalAccuracy: 0.939 train_Precision: 0.935 train_Recall: 0.943
# val_loss: 0.12968787550926208
# val_CategoricalAccuracy: 0.894 val_Precision: 0.906 val_Recall: 0.878
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 30
# train_loss: 0.0780862346291542
# train_CategoricalAccuracy: 0.941 train_Precision: 0.939 train_Recall: 0.943
# val_loss: 0.13566458225250244
# val_CategoricalAccuracy: 0.892 val_Precision: 0.902 val_Recall: 0.880
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 31
# train_loss: 0.08013470470905304
# train_CategoricalAccuracy: 0.938 train_Precision: 0.937 train_Recall: 0.939
# val_loss: 0.12762875854969025
# val_CategoricalAccuracy: 0.890 val_Precision: 0.897 val_Recall: 0.882
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 32
# train_loss: 0.07731854915618896
# train_CategoricalAccuracy: 0.943 train_Precision: 0.942 train_Recall: 0.943
# val_loss: 0.13169671595096588
# val_CategoricalAccuracy: 0.892 val_Precision: 0.908 val_Recall: 0.873
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 33
# train_loss: 0.07679305225610733
# train_CategoricalAccuracy: 0.943 train_Precision: 0.944 train_Recall: 0.941
# val_loss: 0.12011956423521042
# val_CategoricalAccuracy: 0.901 val_Precision: 0.893 val_Recall: 0.912
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 34
# train_loss: 0.07796242088079453
# train_CategoricalAccuracy: 0.942 train_Precision: 0.940 train_Recall: 0.944
# val_loss: 0.1259406954050064
# val_CategoricalAccuracy: 0.894 val_Precision: 0.899 val_Recall: 0.887
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 35
# train_loss: 0.07927955687046051
# train_CategoricalAccuracy: 0.941 train_Precision: 0.941 train_Recall: 0.942
# val_loss: 0.11892075091600418
# val_CategoricalAccuracy: 0.902 val_Precision: 0.894 val_Recall: 0.912
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 36
# train_loss: 0.07467256486415863
# train_CategoricalAccuracy: 0.944 train_Precision: 0.943 train_Recall: 0.946
# val_loss: 0.12897652387619019
# val_CategoricalAccuracy: 0.892 val_Precision: 0.905 val_Recall: 0.876
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 37
# train_loss: 0.07614777982234955
# train_CategoricalAccuracy: 0.942 train_Precision: 0.943 train_Recall: 0.941
# val_loss: 0.1229473203420639
# val_CategoricalAccuracy: 0.899 val_Precision: 0.898 val_Recall: 0.901
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 38
# train_loss: 0.07889378070831299
# train_CategoricalAccuracy: 0.940 train_Precision: 0.937 train_Recall: 0.944
# val_loss: 0.12202544510364532
# val_CategoricalAccuracy: 0.897 val_Precision: 0.898 val_Recall: 0.895
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 39
# train_loss: 0.07445936650037766
# train_CategoricalAccuracy: 0.944 train_Precision: 0.946 train_Recall: 0.943
# val_loss: 0.12093716114759445
# val_CategoricalAccuracy: 0.901 val_Precision: 0.899 val_Recall: 0.904
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 40
# train_loss: 0.07295286655426025
# train_CategoricalAccuracy: 0.947 train_Precision: 0.948 train_Recall: 0.946
# val_loss: 0.11760134249925613
# val_CategoricalAccuracy: 0.906 val_Precision: 0.895 val_Recall: 0.920
#
# ====================================================================================
# Done

# %%
# Get path to folder containing logs 
log_folder = r'E:\baseline-w-normalization\logs-normalize0'

files = glob.glob(log_folder  + "/*.csv")

fig, axes = plt.subplots(1, 1, figsize=(10, 5), sharey=True)
#axes.set_ylim(0.1, 0.20)

for file in files:

    # Read the log file 
    log_file = pd.read_csv(file)

    labell = file.split('\\')[-1].split(".")[0]
    
    # Get the training and validation losses 
    tr_results = log_file[log_file['dataset']=='train']
    va_results = log_file[log_file['dataset']=='val']
    
    # Plot the loss curves 
    sns.lineplot(data=tr_results, x='epoch', y='loss', label= str(labell) + ' train', legend='auto')
    sns.lineplot(data=va_results, x='epoch', y='loss', label=str(labell) + ' val', legend='auto')

# %% [markdown]
# ### Mean 0.5, std dev 1

# %%
main_folder = r'E:\baseline-w-normalization'
spectro_file = main_folder + '\\' + 'spec_config_100-1200Hz-0.032-hamm-normalized0.5.json'
recipe_file = r'E:\final-baseline-detector\resnet_recipe-1.json'
pos_folder = r'E:\final-baseline-detector\annots\pos'
neg_folder = r'E:\final-baseline-detector\annots\neg'
file_durations_file = r'E:\final-baseline-detector\all_file_durations_complete.xlsx'
file_durations = pd.read_excel(file_durations_file)

db_name = main_folder + '\\' + 'final-baseline-db-normalized05.h5'
model_name = main_folder + '\\' + 'final-baseline-model-normalized05.kt'
temp_folder = main_folder + '\\' + 'rs-temp'

data_folder = r'D:\ringed-seal-data'

# %%
# join into a database
# Load the spectrogram representation & parameters, this returns a dict 
spec_cfg = load_audio_representation(spectro_file, name="spectrogram")

# Create a table called "train" in the database, defined by db_name, using the "train" selections table, the spectrogram config, and the audio data 
# Behind the hood, this creates an AudioLoader and AudioWriter Ketos function which generates the spectrograms for each selection 
dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'train', selections=train, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'val', selections=val, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'test', selections=test, data_dir=data_folder,
                    audio_repres=spec_cfg)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6362/6362 [02:42<00:00, 39.21it/s]
# 6362 items saved to E:\baseline-w-normalization\final-baseline-db-normalized05.h5
# 100%|██████████████████████████████████████████████████████████████████████████████| 1813/1813 [00:43<00:00, 41.40it/s]
# 1813 items saved to E:\baseline-w-normalization\final-baseline-db-normalized05.h5
# 100%|████████████████████████████████████████████████████████████████████████████████| 894/894 [00:21<00:00, 42.31it/s]
# 894 items saved to E:\baseline-w-normalization\final-baseline-db-normalized05.h5

# %%
# Set the random seed for numpy and tensorflow 
np.random.seed(1000)
tf.random.set_seed(2000)

# Set the batch size and number of epochs for training
batch_size = 16
n_epochs = 40

# Set the log folder and checkpoint folder 
log_folder = main_folder + '\\' + 'logs-normalize05'
checkpoint_folder = main_folder + '\\' + 'checkpoints-normalize05'

# Open the database file in read mode
db = dbi.open_file(db_name, 'r')

# Open the training and validation tables respectively 
train_data = dbi.open_table(db, "/train/data")
val_data = dbi.open_table(db, "/val/data")

# Create batches of training data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
train_generator = BatchGenerator(batch_size=batch_size, data_table=train_data,
                                    output_transform_func=ResNetInterface.transform_batch,
                                    shuffle=True, refresh_on_epoch_end=True)

# Create batches of validation data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
val_generator = BatchGenerator(batch_size=batch_size, data_table=val_data,
                                   output_transform_func=ResNetInterface.transform_batch,
                                   shuffle=False, refresh_on_epoch_end=False)

# Build the ResNet model file based off of the recipe file - this creates a "ResNetInterface" object 
resnet = ResNetInterface.build(recipe_file)

# Set the training and validation generators to the batch generators created above 
resnet.train_generator = train_generator
resnet.val_generator = val_generator

# Set the model log and checkpoint directory 
resnet.log_dir = log_folder
resnet.checkpoint_dir = checkpoint_folder

# Train the model, looping through all of the training and validation data 
# See code map for more information
resnet.train_loop(n_epochs=n_epochs, verbose=True, log_csv=True, csv_name='log-hamm-0.32-manual.csv')

# Close the database 
db.close()

# Save the model file, and keep track of the spectrogram parameters used to generate that model 
resnet.save(model_name, audio_repr_file=spectro_file)

print('Done')
# Out:
# ====================================================================================
# Epoch: 1
# train_loss: 0.23876328766345978
# train_CategoricalAccuracy: 0.801 train_Precision: 0.844 train_Recall: 0.738
# val_loss: 0.3119749426841736
# val_CategoricalAccuracy: 0.685 val_Precision: 0.863 val_Recall: 0.439
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 2
# train_loss: 0.16584822535514832
# train_CategoricalAccuracy: 0.866 train_Precision: 0.879 train_Recall: 0.848
# val_loss: 0.2515544295310974
# val_CategoricalAccuracy: 0.760 val_Precision: 0.894 val_Recall: 0.588
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 3
# train_loss: 0.14173951745033264
# train_CategoricalAccuracy: 0.889 train_Precision: 0.901 train_Recall: 0.873
# val_loss: 0.1690494418144226
# val_CategoricalAccuracy: 0.863 val_Precision: 0.865 val_Recall: 0.859
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 4
# train_loss: 0.1339392066001892
# train_CategoricalAccuracy: 0.893 train_Precision: 0.902 train_Recall: 0.881
# val_loss: 0.17616716027259827
# val_CategoricalAccuracy: 0.864 val_Precision: 0.903 val_Recall: 0.815
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 5
# train_loss: 0.12437745183706284
# train_CategoricalAccuracy: 0.902 train_Precision: 0.911 train_Recall: 0.892
# val_loss: 0.17167912423610687
# val_CategoricalAccuracy: 0.842 val_Precision: 0.897 val_Recall: 0.771
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 6
# train_loss: 0.12274353206157684
# train_CategoricalAccuracy: 0.903 train_Precision: 0.908 train_Recall: 0.896
# val_loss: 0.15933044254779816
# val_CategoricalAccuracy: 0.873 val_Precision: 0.880 val_Recall: 0.864
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 7
# train_loss: 0.1168745681643486
# train_CategoricalAccuracy: 0.908 train_Precision: 0.911 train_Recall: 0.903
# val_loss: 0.12959109246730804
# val_CategoricalAccuracy: 0.896 val_Precision: 0.883 val_Recall: 0.914
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 8
# train_loss: 0.11350367218255997
# train_CategoricalAccuracy: 0.907 train_Precision: 0.908 train_Recall: 0.905
# val_loss: 0.16230320930480957
# val_CategoricalAccuracy: 0.875 val_Precision: 0.892 val_Recall: 0.853
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 9
# train_loss: 0.10595712810754776
# train_CategoricalAccuracy: 0.916 train_Precision: 0.919 train_Recall: 0.912
# val_loss: 0.13327233493328094
# val_CategoricalAccuracy: 0.891 val_Precision: 0.880 val_Recall: 0.906
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 10
# train_loss: 0.10472666472196579
# train_CategoricalAccuracy: 0.916 train_Precision: 0.917 train_Recall: 0.913
# val_loss: 0.17307895421981812
# val_CategoricalAccuracy: 0.854 val_Precision: 0.905 val_Recall: 0.791
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 11
# train_loss: 0.1041523739695549
# train_CategoricalAccuracy: 0.918 train_Precision: 0.920 train_Recall: 0.916
# val_loss: 0.13858334720134735
# val_CategoricalAccuracy: 0.884 val_Precision: 0.896 val_Recall: 0.869
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 12
# train_loss: 0.09860455989837646
# train_CategoricalAccuracy: 0.923 train_Precision: 0.923 train_Recall: 0.924
# val_loss: 0.12939658761024475
# val_CategoricalAccuracy: 0.894 val_Precision: 0.863 val_Recall: 0.937
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 13
# train_loss: 0.09960267692804337
# train_CategoricalAccuracy: 0.923 train_Precision: 0.925 train_Recall: 0.922
# val_loss: 0.12114985287189484
# val_CategoricalAccuracy: 0.908 val_Precision: 0.868 val_Recall: 0.962
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 14
# train_loss: 0.09410881996154785
# train_CategoricalAccuracy: 0.927 train_Precision: 0.922 train_Recall: 0.933
# val_loss: 0.12577944993972778
# val_CategoricalAccuracy: 0.901 val_Precision: 0.884 val_Recall: 0.924
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 15
# train_loss: 0.09331231564283371
# train_CategoricalAccuracy: 0.928 train_Precision: 0.927 train_Recall: 0.929
# val_loss: 0.13855840265750885
# val_CategoricalAccuracy: 0.891 val_Precision: 0.901 val_Recall: 0.878
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 16
# train_loss: 0.09100796282291412
# train_CategoricalAccuracy: 0.931 train_Precision: 0.927 train_Recall: 0.935
# val_loss: 0.12037024646997452
# val_CategoricalAccuracy: 0.906 val_Precision: 0.903 val_Recall: 0.908
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 17
# train_loss: 0.09218431264162064
# train_CategoricalAccuracy: 0.929 train_Precision: 0.922 train_Recall: 0.936
# val_loss: 0.14138497412204742
# val_CategoricalAccuracy: 0.882 val_Precision: 0.910 val_Recall: 0.848
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 18
# train_loss: 0.08942117542028427
# train_CategoricalAccuracy: 0.931 train_Precision: 0.930 train_Recall: 0.933
# val_loss: 0.1140691488981247
# val_CategoricalAccuracy: 0.913 val_Precision: 0.878 val_Recall: 0.960
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 19
# train_loss: 0.08639472723007202
# train_CategoricalAccuracy: 0.935 train_Precision: 0.934 train_Recall: 0.936
# val_loss: 0.12384654581546783
# val_CategoricalAccuracy: 0.900 val_Precision: 0.872 val_Recall: 0.936
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 20
# train_loss: 0.0860537588596344
# train_CategoricalAccuracy: 0.936 train_Precision: 0.937 train_Recall: 0.935
# val_loss: 0.12243955582380295
# val_CategoricalAccuracy: 0.901 val_Precision: 0.894 val_Recall: 0.909
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 21
# train_loss: 0.08426997065544128
# train_CategoricalAccuracy: 0.936 train_Precision: 0.936 train_Recall: 0.937
# val_loss: 0.12094908207654953
# val_CategoricalAccuracy: 0.901 val_Precision: 0.889 val_Recall: 0.915
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 22
# train_loss: 0.08209580928087234
# train_CategoricalAccuracy: 0.942 train_Precision: 0.940 train_Recall: 0.944
# val_loss: 0.11693073064088821
# val_CategoricalAccuracy: 0.908 val_Precision: 0.874 val_Recall: 0.955
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 23
# train_loss: 0.0839688628911972
# train_CategoricalAccuracy: 0.935 train_Precision: 0.934 train_Recall: 0.937
# val_loss: 0.1339869648218155
# val_CategoricalAccuracy: 0.891 val_Precision: 0.913 val_Recall: 0.865
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 24
# train_loss: 0.08328139781951904
# train_CategoricalAccuracy: 0.936 train_Precision: 0.936 train_Recall: 0.936
# val_loss: 0.11258148401975632
# val_CategoricalAccuracy: 0.910 val_Precision: 0.890 val_Recall: 0.934
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 25
# train_loss: 0.08285214751958847
# train_CategoricalAccuracy: 0.936 train_Precision: 0.931 train_Recall: 0.941
# val_loss: 0.11917908489704132
# val_CategoricalAccuracy: 0.909 val_Precision: 0.908 val_Recall: 0.909
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 26
# train_loss: 0.08042942732572556
# train_CategoricalAccuracy: 0.941 train_Precision: 0.941 train_Recall: 0.940
# val_loss: 0.11840403079986572
# val_CategoricalAccuracy: 0.906 val_Precision: 0.909 val_Recall: 0.902
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 27
# train_loss: 0.0786086916923523
# train_CategoricalAccuracy: 0.943 train_Precision: 0.942 train_Recall: 0.943
# val_loss: 0.12393692135810852
# val_CategoricalAccuracy: 0.901 val_Precision: 0.911 val_Recall: 0.887
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 28
# train_loss: 0.07405363768339157
# train_CategoricalAccuracy: 0.947 train_Precision: 0.948 train_Recall: 0.945
# val_loss: 0.11564244329929352
# val_CategoricalAccuracy: 0.909 val_Precision: 0.908 val_Recall: 0.909
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 29
# train_loss: 0.07801255583763123
# train_CategoricalAccuracy: 0.942 train_Precision: 0.938 train_Recall: 0.945
# val_loss: 0.12080477923154831
# val_CategoricalAccuracy: 0.907 val_Precision: 0.915 val_Recall: 0.897
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 30
# train_loss: 0.0754394605755806
# train_CategoricalAccuracy: 0.945 train_Precision: 0.947 train_Recall: 0.943
# val_loss: 0.1387896090745926
# val_CategoricalAccuracy: 0.890 val_Precision: 0.926 val_Recall: 0.846
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 31
# train_loss: 0.07686910033226013
# train_CategoricalAccuracy: 0.944 train_Precision: 0.947 train_Recall: 0.942
# val_loss: 0.11449519544839859
# val_CategoricalAccuracy: 0.905 val_Precision: 0.894 val_Recall: 0.917
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 32
# train_loss: 0.074301578104496
# train_CategoricalAccuracy: 0.946 train_Precision: 0.949 train_Recall: 0.943
# val_loss: 0.11527616530656815
# val_CategoricalAccuracy: 0.910 val_Precision: 0.905 val_Recall: 0.915
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 33
# train_loss: 0.07346190512180328
# train_CategoricalAccuracy: 0.946 train_Precision: 0.946 train_Recall: 0.945
# val_loss: 0.12286841869354248
# val_CategoricalAccuracy: 0.904 val_Precision: 0.913 val_Recall: 0.893
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 34
# train_loss: 0.07450224459171295
# train_CategoricalAccuracy: 0.947 train_Precision: 0.948 train_Recall: 0.945
# val_loss: 0.12612958252429962
# val_CategoricalAccuracy: 0.901 val_Precision: 0.920 val_Recall: 0.877
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 35
# train_loss: 0.07707476615905762
# train_CategoricalAccuracy: 0.945 train_Precision: 0.946 train_Recall: 0.945
# val_loss: 0.11374854296445847
# val_CategoricalAccuracy: 0.913 val_Precision: 0.914 val_Recall: 0.912
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 36
# train_loss: 0.0711711123585701
# train_CategoricalAccuracy: 0.950 train_Precision: 0.951 train_Recall: 0.949
# val_loss: 0.1147865280508995
# val_CategoricalAccuracy: 0.908 val_Precision: 0.912 val_Recall: 0.904
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 37
# train_loss: 0.07084956765174866
# train_CategoricalAccuracy: 0.950 train_Precision: 0.952 train_Recall: 0.947
# val_loss: 0.11472882330417633
# val_CategoricalAccuracy: 0.910 val_Precision: 0.910 val_Recall: 0.908
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 38
# train_loss: 0.07278211414813995
# train_CategoricalAccuracy: 0.947 train_Precision: 0.950 train_Recall: 0.944
# val_loss: 0.10743775218725204
# val_CategoricalAccuracy: 0.915 val_Precision: 0.895 val_Recall: 0.939
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 39
# train_loss: 0.06989524513483047
# train_CategoricalAccuracy: 0.949 train_Precision: 0.951 train_Recall: 0.946
# val_loss: 0.1260739415884018
# val_CategoricalAccuracy: 0.900 val_Precision: 0.918 val_Recall: 0.878
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 40
# train_loss: 0.06838539242744446
# train_CategoricalAccuracy: 0.954 train_Precision: 0.958 train_Recall: 0.949
# val_loss: 0.11367829889059067
# val_CategoricalAccuracy: 0.913 val_Precision: 0.908 val_Recall: 0.918
#
# ====================================================================================
# Done

# %%
# Get path to folder containing logs 
log_folder = r'E:\baseline-w-normalization\logs-normalize05'

files = glob.glob(log_folder  + "/*.csv")

fig, axes = plt.subplots(1, 1, figsize=(10, 5), sharey=True)
#axes.set_ylim(0.1, 0.20)

for file in files:

    # Read the log file 
    log_file = pd.read_csv(file)

    labell = file.split('\\')[-1].split(".")[0]
    
    # Get the training and validation losses 
    tr_results = log_file[log_file['dataset']=='train']
    va_results = log_file[log_file['dataset']=='val']
    
    # Plot the loss curves 
    sns.lineplot(data=tr_results, x='epoch', y='loss', label= str(labell) + ' train', legend='auto')
    sns.lineplot(data=va_results, x='epoch', y='loss', label=str(labell) + ' val', legend='auto')

# %% [markdown]
# ### Adjust Range

# %%
main_folder = r'E:\baseline-w-normalization'
spectro_file = main_folder + '\\' + 'spec_config_100-1200Hz-0.032-hamm-adjustrange.json'
recipe_file = r'E:\final-baseline-detector\resnet_recipe-1.json'
pos_folder = r'E:\final-baseline-detector\annots\pos'
neg_folder = r'E:\final-baseline-detector\annots\neg'
file_durations_file = r'E:\final-baseline-detector\all_file_durations_complete.xlsx'
file_durations = pd.read_excel(file_durations_file)

db_name = main_folder + '\\' + 'final-baseline-db-adjustrange.h5'
model_name = main_folder + '\\' + 'final-baseline-model-adjustrange.kt'
temp_folder = main_folder + '\\' + 'rs-temp'

data_folder = r'D:\ringed-seal-data'

# %%
# join into a database
# Load the spectrogram representation & parameters, this returns a dict 
spec_cfg = load_audio_representation(spectro_file, name="spectrogram")

# Create a table called "train" in the database, defined by db_name, using the "train" selections table, the spectrogram config, and the audio data 
# Behind the hood, this creates an AudioLoader and AudioWriter Ketos function which generates the spectrograms for each selection 
dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'train', selections=train, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'val', selections=val, data_dir=data_folder,
                    audio_repres=spec_cfg)

dbi.create_database(output_file=db_name,  # empty brackets
                    dataset_name=r'test', selections=test, data_dir=data_folder,
                    audio_repres=spec_cfg)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6362/6362 [02:47<00:00, 38.02it/s]
# 6362 items saved to E:\baseline-w-normalization\final-baseline-db-adjustrange.h5
# 100%|██████████████████████████████████████████████████████████████████████████████| 1813/1813 [00:43<00:00, 41.77it/s]
# 1813 items saved to E:\baseline-w-normalization\final-baseline-db-adjustrange.h5
# 100%|████████████████████████████████████████████████████████████████████████████████| 894/894 [00:21<00:00, 41.68it/s]
# 894 items saved to E:\baseline-w-normalization\final-baseline-db-adjustrange.h5

# %%
# Set the random seed for numpy and tensorflow 
np.random.seed(1000)
tf.random.set_seed(2000)

# Set the batch size and number of epochs for training
batch_size = 16
n_epochs = 40

# Set the log folder and checkpoint folder 
log_folder = main_folder + '\\' + 'logs-adjustrange'
checkpoint_folder = main_folder + '\\' + 'checkpoints-adjustrange'

# Open the database file in read mode
db = dbi.open_file(db_name, 'r')

# Open the training and validation tables respectively 
train_data = dbi.open_table(db, "/train/data")
val_data = dbi.open_table(db, "/val/data")

# Create batches of training data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
train_generator = BatchGenerator(batch_size=batch_size, data_table=train_data,
                                    output_transform_func=ResNetInterface.transform_batch,
                                    shuffle=True, refresh_on_epoch_end=True)

# Create batches of validation data of size batch size, using the specified data table 
# This returns indices of the data in each batch along with their labels 
val_generator = BatchGenerator(batch_size=batch_size, data_table=val_data,
                                   output_transform_func=ResNetInterface.transform_batch,
                                   shuffle=False, refresh_on_epoch_end=False)

# Build the ResNet model file based off of the recipe file - this creates a "ResNetInterface" object 
resnet = ResNetInterface.build(recipe_file)

# Set the training and validation generators to the batch generators created above 
resnet.train_generator = train_generator
resnet.val_generator = val_generator

# Set the model log and checkpoint directory 
resnet.log_dir = log_folder
resnet.checkpoint_dir = checkpoint_folder

# Train the model, looping through all of the training and validation data 
# See code map for more information
resnet.train_loop(n_epochs=n_epochs, verbose=True, log_csv=True, csv_name='log-hamm-0.32-manual.csv')

# Close the database 
db.close()

# Save the model file, and keep track of the spectrogram parameters used to generate that model 
resnet.save(model_name, audio_repr_file=spectro_file)

print('Done')
# Out:
# ====================================================================================
# Epoch: 1
# train_loss: 0.14030885696411133
# train_CategoricalAccuracy: 0.866 train_Precision: 0.854 train_Recall: 0.883
# val_loss: 0.1470361202955246
# val_CategoricalAccuracy: 0.861 val_Precision: 0.811 val_Recall: 0.940
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 2
# train_loss: 0.1186743974685669
# train_CategoricalAccuracy: 0.886 train_Precision: 0.866 train_Recall: 0.912
# val_loss: 0.49944713711738586
# val_CategoricalAccuracy: 0.499 val_Precision: 0.499 val_Recall: 1.000
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 3
# train_loss: 0.10998839139938354
# train_CategoricalAccuracy: 0.893 train_Precision: 0.876 train_Recall: 0.915
# val_loss: 0.4875917136669159
# val_CategoricalAccuracy: 0.507 val_Precision: 0.503 val_Recall: 1.000
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 4
# train_loss: 0.10584385693073273
# train_CategoricalAccuracy: 0.898 train_Precision: 0.879 train_Recall: 0.924
# val_loss: 0.1636478751897812
# val_CategoricalAccuracy: 0.844 val_Precision: 0.773 val_Recall: 0.975
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 5
# train_loss: 0.0990314856171608
# train_CategoricalAccuracy: 0.906 train_Precision: 0.905 train_Recall: 0.907
# val_loss: 0.2411670982837677
# val_CategoricalAccuracy: 0.769 val_Precision: 0.685 val_Recall: 0.992
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 6
# train_loss: 0.0955205112695694
# train_CategoricalAccuracy: 0.911 train_Precision: 0.906 train_Recall: 0.917
# val_loss: 0.22727593779563904
# val_CategoricalAccuracy: 0.777 val_Precision: 0.694 val_Recall: 0.988
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 7
# train_loss: 0.08806486427783966
# train_CategoricalAccuracy: 0.917 train_Precision: 0.914 train_Recall: 0.922
# val_loss: 0.4783608317375183
# val_CategoricalAccuracy: 0.521 val_Precision: 0.511 val_Recall: 0.991
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 8
# train_loss: 0.0872758999466896
# train_CategoricalAccuracy: 0.918 train_Precision: 0.914 train_Recall: 0.924
# val_loss: 0.11775430291891098
# val_CategoricalAccuracy: 0.889 val_Precision: 0.927 val_Recall: 0.843
#
# ====================================================================================
#
# ====================================================================================
# Epoch: 9
# train_loss: 0.08169588446617126
# train_CategoricalAccuracy: 0.924 train_Precision: 0.920 train_Recall: 0.928
# val_loss: 0.32794007658958435
# val_CategoricalAccuracy: 0.662 val_Precision: 0.597 val_Recall: 0.998
#
# ====================================================================================
# KeyboardInterrupt

# %%
# Get path to folder containing logs 
log_folder = r'E:\baseline-w-normalization\logs-adjustrange'

files = glob.glob(log_folder  + "/*.csv")

fig, axes = plt.subplots(1, 1, figsize=(10, 5), sharey=True)
axes.set_ylim(0.0, 0.35)

for file in files:

    # Read the log file 
    log_file = pd.read_csv(file)

    labell = file.split('\\')[-1].split(".")[0]
    
    # Get the training and validation losses 
    tr_results = log_file[log_file['dataset']=='train']
    va_results = log_file[log_file['dataset']=='val']
    
    # Plot the loss curves 
    sns.lineplot(data=tr_results, x='epoch', y='loss', label= str(labell) + ' train', legend='auto')
    sns.lineplot(data=va_results, x='epoch', y='loss', label=str(labell) + ' val', legend='auto')

# %% [markdown]
# ## Test Models

# %%
def compute_detections(labels, scores, threshold=0.5):

    # Compute the positive scores above threshold, 1 if it is above threshold, 0 if it is not 
    predictions = np.where(scores >= threshold, 1,0)

    # TP: Does the annotated label match the prediction above threshold? Bc "scores" is defined as the positive threshold, this represents TP
    TP = tf.math.count_nonzero(predictions * labels).numpy()

    # TN: Negative score is "predictions - 1" bc predictions was for the positive result, labels-1 so that the negatives are multiplied by 1
    TN = tf.math.count_nonzero((predictions - 1) * (labels - 1)).numpy()

    # And so on 
    FP = tf.math.count_nonzero(predictions * (labels - 1)).numpy()
    FN = tf.math.count_nonzero((predictions - 1) * labels).numpy()

    return predictions, TP, TN, FP, FN

# %%
def confusion_matrix_plot(cf, output_folder,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=True):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.

    Arguments
    ---------
    cf:            confusion matrix to be passed in

    group_names:   List of strings that represent the labels row by row to be shown in each square.

    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'

    count:         If True, show the raw number in the confusion matrix. Default is True.

    normalize:     If True, show the proportions for each category. Default is True.

    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.

    xyticks:       If True, show x and y ticks. Default is True.

    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.

    sum_stats:     If True, display summary statistics below the figure. Default is True.

    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.

    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html

    title:         Title for the heatmap. Default is None.

    '''

    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names) == cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten() / np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels, group_counts, group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0], cf.shape[1])

    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        # Accuracy is sum of diagonal divided by total observations
        accuracy = np.trace(cf) / float(np.sum(cf))

        # if it is a binary confusion matrix, show some more stats
        if len(cf) == 2:
            # Metrics for Binary Confusion Matrices
            precision = cf[1, 1] / sum(cf[:, 1])
            recall = cf[1, 1] / sum(cf[1, :])
            f1_score = 2 * precision * recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy, precision, recall, f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""

    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize == None:
        # Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks == False:
        # Do not show categories if xyticks is False
        categories = False

    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf, annot=box_labels, fmt="", cmap=cmap, cbar=cbar, xticklabels=categories, yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        #plt.xlabel('Predicted label' + stats_text)
        plt.xlabel('Predicted label')
    else:
        plt.xlabel(stats_text)

    if title:
        #plt.title(title)
        #plt.title(stats_text)
        print('Confusion Matrix')

    plt.savefig(output_folder + '\\' + 'confusion_matrix.png')

# %% [markdown]
# ### Mean 0, Std dev 1

# %%
thresholds = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
#thresholds = [0.4]
step_size = 1.0
batch_size = 16
buffer = 0.5

# Get pathway to metrics folder
output_dir = r'E:\baseline-w-normalization\metrics-normalize0'
main_folder = r'E:\baseline-w-normalization'
db_name = main_folder + '\\' + 'final-baseline-db-normalized0.h5'
model_name = main_folder + '\\' + 'final-baseline-model-normalized0.kt'
temp_folder = main_folder + '\\' + 'temp-normalized0'

# Open the database in read only file
db = dbi.open_file(db_name, 'r')

# Open the table in the database at the root level
table = dbi.open_table(db, '/test')

classification_csv = "classifications.csv"
metric_csv = "metrics.csv"
stats_csv = "stats.csv"

# Load the trained model
model = ResNetInterface.load(model_name, load_audio_repr=False, new_model_folder=temp_folder)

# Initialize Joint Batch Generator
gens = []

# Calculate the batch_size fixing the original batch size so there are no remainders
batch_size = int(batch_size / sum(1 for _ in db.walk_nodes(table, "Table")))

# for the testing dataset table in the database (or whatever table is passed in)
for group in db.walk_nodes(table, "Table"):
    # Create a batch generator for this table
    generator = BatchGenerator(batch_size=batch_size, data_table=group,
                               output_transform_func=ResNetInterface.transform_batch, shuffle=False,
                               refresh_on_epoch_end=False, x_field='data', return_batch_ids=True)

    # Append the generator to the gens array
    gens.append(generator)

# Create a joint batch generator if multiple tables are passed through
gen = JointBatchGen(gens, n_batches='min', shuffle_batch=False, reset_generators=False, return_batch_ids=True)

# Initialize the scores and labels
scores = []
labels = []

# For each batch in the joint batch generator
for batch_id in range(gen.n_batches):
    # Get the ids, spectrograms, and labels for the data in the batch
    hdf5_ids, batch_X, batch_Y = next(gen)

    # Get the labels for the batch data, using the "argmax" func which returns the col header, so 0 is a noise segment, 1 is a rs segment
    batch_labels = np.argmax(batch_Y, axis=1)

    # Returns the scores for the batch for the "positive" class - this is used in the compute detections function later on
    batch_scores = model.model.predict_on_batch(batch_X)[:, 1]

    # Add these scores for this batch to the overall list
    scores.extend(batch_scores)
    labels.extend(batch_labels)

# Create a numpy array for the labels and scores for all batches
labels = np.array(labels)
scores = np.array(scores)

df_groups = pd.DataFrame()
df_stats = pd.DataFrame(columns = ['threshold', 'precision', 'recall', 'f1', 'FPP'])

for threshold in thresholds:

    df_group = pd.DataFrame()

    # Compute the predictions, TP, TN, FP, and FN
    # Predicted is an array are greater than a certain threshold, 1 for the score was, 0 for it was not
    predicted, TP, TN, FP, FN = compute_detections(labels, scores, threshold)

    # Create the "classifications" csv file
    for group in db.walk_nodes(table, "Table"):
        df = pd.DataFrame({'id': group[:]['id'], 'filename': group[:]['filename']})
        df_group = pd.concat([df_group, df], ignore_index=True)
    df_group['threshold'] = threshold
    df_group['label'] = labels[:]
    df_group['predicted'] = predicted[:]
    df_group['score'] = scores[:]

    # Calculate performance metrics
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)
    FPP = FP / (TN + FP)

    stats = [threshold, precision, recall, f1, FPP]

    df_groups = pd.concat([df_groups, df_group])
    df_stats.loc[len(df_stats)] = stats

df_groups.to_csv(os.path.join(os.getcwd(), output_dir, classification_csv), mode='w', index=False)
df_stats.to_csv(os.path.join(os.getcwd(), output_dir, stats_csv), mode='w', index=False)

sns.lineplot(x='threshold', y='value', hue='variable', data=pd.melt(df_stats, ['threshold']))
plt.title(model_name)

db.close()

# %%
threshold = 0.6

classifications_file = r'E:\baseline-w-normalization\metrics-normalize0\classifications.csv'

classifications = pd.read_csv(classifications_file)

classifications_by_threshold = classifications[classifications['threshold']==threshold]

predictions = classifications_by_threshold['predicted']

labels = classifications_by_threshold['label']

cm = confusion_matrix_sklearn(predictions, labels)

labels = ['True Pos', 'False Neg', 'False Pos', 'True Neg']
categories = ['Ringed Seal', 'Noise']

confusion_matrix_plot(cm, output_dir, group_names=labels, categories=categories, cmap='viridis')
# Out:
# Confusion Matrix

# %% [markdown]
# ### Mean 0.5, std dev 1

# %%
thresholds = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
#thresholds = [0.4]
step_size = 1.0
batch_size = 16
buffer = 0.5

# Get pathway to metrics folder
output_dir = r'E:\baseline-w-normalization\metrics-normalize05'
main_folder = r'E:\baseline-w-normalization'
db_name = main_folder + '\\' + 'final-baseline-db-normalized05.h5'
model_name = main_folder + '\\' + 'final-baseline-model-normalized05.kt'
temp_folder = main_folder + '\\' + 'temp-normalized05'

# Open the database in read only file
db = dbi.open_file(db_name, 'r')

# Open the table in the database at the root level
table = dbi.open_table(db, '/test')

classification_csv = "classifications.csv"
metric_csv = "metrics.csv"
stats_csv = "stats.csv"

# Load the trained model
model = ResNetInterface.load(model_name, load_audio_repr=False, new_model_folder=temp_folder)

# Initialize Joint Batch Generator
gens = []

# Calculate the batch_size fixing the original batch size so there are no remainders
batch_size = int(batch_size / sum(1 for _ in db.walk_nodes(table, "Table")))

# for the testing dataset table in the database (or whatever table is passed in)
for group in db.walk_nodes(table, "Table"):
    # Create a batch generator for this table
    generator = BatchGenerator(batch_size=batch_size, data_table=group,
                               output_transform_func=ResNetInterface.transform_batch, shuffle=False,
                               refresh_on_epoch_end=False, x_field='data', return_batch_ids=True)

    # Append the generator to the gens array
    gens.append(generator)

# Create a joint batch generator if multiple tables are passed through
gen = JointBatchGen(gens, n_batches='min', shuffle_batch=False, reset_generators=False, return_batch_ids=True)

# Initialize the scores and labels
scores = []
labels = []

# For each batch in the joint batch generator
for batch_id in range(gen.n_batches):
    # Get the ids, spectrograms, and labels for the data in the batch
    hdf5_ids, batch_X, batch_Y = next(gen)

    # Get the labels for the batch data, using the "argmax" func which returns the col header, so 0 is a noise segment, 1 is a rs segment
    batch_labels = np.argmax(batch_Y, axis=1)

    # Returns the scores for the batch for the "positive" class - this is used in the compute detections function later on
    batch_scores = model.model.predict_on_batch(batch_X)[:, 1]

    # Add these scores for this batch to the overall list
    scores.extend(batch_scores)
    labels.extend(batch_labels)

# Create a numpy array for the labels and scores for all batches
labels = np.array(labels)
scores = np.array(scores)

df_groups = pd.DataFrame()
df_stats = pd.DataFrame(columns = ['threshold', 'precision', 'recall', 'f1', 'FPP'])

for threshold in thresholds:

    df_group = pd.DataFrame()

    # Compute the predictions, TP, TN, FP, and FN
    # Predicted is an array are greater than a certain threshold, 1 for the score was, 0 for it was not
    predicted, TP, TN, FP, FN = compute_detections(labels, scores, threshold)

    # Create the "classifications" csv file
    for group in db.walk_nodes(table, "Table"):
        df = pd.DataFrame({'id': group[:]['id'], 'filename': group[:]['filename']})
        df_group = pd.concat([df_group, df], ignore_index=True)
    df_group['threshold'] = threshold
    df_group['label'] = labels[:]
    df_group['predicted'] = predicted[:]
    df_group['score'] = scores[:]

    # Calculate performance metrics
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)
    FPP = FP / (TN + FP)

    stats = [threshold, precision, recall, f1, FPP]

    df_groups = pd.concat([df_groups, df_group])
    df_stats.loc[len(df_stats)] = stats

df_groups.to_csv(os.path.join(os.getcwd(), output_dir, classification_csv), mode='w', index=False)
df_stats.to_csv(os.path.join(os.getcwd(), output_dir, stats_csv), mode='w', index=False)

sns.lineplot(x='threshold', y='value', hue='variable', data=pd.melt(df_stats, ['threshold']))
plt.title(model_name)

db.close()

# %%
threshold = 0.6

classifications_file = r'E:\baseline-w-normalization\metrics-normalize05\classifications.csv'

classifications = pd.read_csv(classifications_file)

classifications_by_threshold = classifications[classifications['threshold']==threshold]

predictions = classifications_by_threshold['predicted']

labels = classifications_by_threshold['label']

cm = confusion_matrix_sklearn(predictions, labels)

labels = ['True Pos', 'False Neg', 'False Pos', 'True Neg']
categories = ['Ringed Seal', 'Noise']

confusion_matrix_plot(cm, output_dir, group_names=labels, categories=categories, cmap='viridis')
# Out:
# Confusion Matrix

# %% [markdown]
# ### Adjust Range

# %%
thresholds = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
#thresholds = [0.4]
step_size = 1.0
batch_size = 16
buffer = 0.5

# Get pathway to metrics folder
output_dir = r'E:\baseline-w-normalization\metrics-adjustrange'
main_folder = r'E:\baseline-w-normalization'
db_name = main_folder + '\\' + 'final-baseline-db-adjustrange.h5'
model_name = main_folder + '\\' + 'final-baseline-model-adjustrange.kt'
temp_folder = main_folder + '\\' + 'temp-adjustrange'

# Open the database in read only file
db = dbi.open_file(db_name, 'r')

# Open the table in the database at the root level
table = dbi.open_table(db, '/test')

classification_csv = "classifications.csv"
metric_csv = "metrics.csv"
stats_csv = "stats.csv"

# Load the trained model
model = ResNetInterface.load(model_name, load_audio_repr=False, new_model_folder=temp_folder)

# Initialize Joint Batch Generator
gens = []

# Calculate the batch_size fixing the original batch size so there are no remainders
batch_size = int(batch_size / sum(1 for _ in db.walk_nodes(table, "Table")))

# for the testing dataset table in the database (or whatever table is passed in)
for group in db.walk_nodes(table, "Table"):
    # Create a batch generator for this table
    generator = BatchGenerator(batch_size=batch_size, data_table=group,
                               output_transform_func=ResNetInterface.transform_batch, shuffle=False,
                               refresh_on_epoch_end=False, x_field='data', return_batch_ids=True)

    # Append the generator to the gens array
    gens.append(generator)

# Create a joint batch generator if multiple tables are passed through
gen = JointBatchGen(gens, n_batches='min', shuffle_batch=False, reset_generators=False, return_batch_ids=True)

# Initialize the scores and labels
scores = []
labels = []

# For each batch in the joint batch generator
for batch_id in range(gen.n_batches):
    # Get the ids, spectrograms, and labels for the data in the batch
    hdf5_ids, batch_X, batch_Y = next(gen)

    # Get the labels for the batch data, using the "argmax" func which returns the col header, so 0 is a noise segment, 1 is a rs segment
    batch_labels = np.argmax(batch_Y, axis=1)

    # Returns the scores for the batch for the "positive" class - this is used in the compute detections function later on
    batch_scores = model.model.predict_on_batch(batch_X)[:, 1]

    # Add these scores for this batch to the overall list
    scores.extend(batch_scores)
    labels.extend(batch_labels)

# Create a numpy array for the labels and scores for all batches
labels = np.array(labels)
scores = np.array(scores)

df_groups = pd.DataFrame()
df_stats = pd.DataFrame(columns = ['threshold', 'precision', 'recall', 'f1', 'FPP'])

for threshold in thresholds:

    df_group = pd.DataFrame()

    # Compute the predictions, TP, TN, FP, and FN
    # Predicted is an array are greater than a certain threshold, 1 for the score was, 0 for it was not
    predicted, TP, TN, FP, FN = compute_detections(labels, scores, threshold)

    # Create the "classifications" csv file
    for group in db.walk_nodes(table, "Table"):
        df = pd.DataFrame({'id': group[:]['id'], 'filename': group[:]['filename']})
        df_group = pd.concat([df_group, df], ignore_index=True)
    df_group['threshold'] = threshold
    df_group['label'] = labels[:]
    df_group['predicted'] = predicted[:]
    df_group['score'] = scores[:]

    # Calculate performance metrics
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)
    FPP = FP / (TN + FP)

    stats = [threshold, precision, recall, f1, FPP]

    df_groups = pd.concat([df_groups, df_group])
    df_stats.loc[len(df_stats)] = stats

df_groups.to_csv(os.path.join(os.getcwd(), output_dir, classification_csv), mode='w', index=False)
df_stats.to_csv(os.path.join(os.getcwd(), output_dir, stats_csv), mode='w', index=False)

sns.lineplot(x='threshold', y='value', hue='variable', data=pd.melt(df_stats, ['threshold']))
plt.title(model_name)

db.close()

# %%
threshold = 0.6

classifications_file = r'E:\baseline-w-normalization\metrics-adjustrange\classifications.csv'

classifications = pd.read_csv(classifications_file)

classifications_by_threshold = classifications[classifications['threshold']==threshold]

predictions = classifications_by_threshold['predicted']

labels = classifications_by_threshold['label']

cm = confusion_matrix_sklearn(predictions, labels)

labels = ['True Pos', 'False Neg', 'False Pos', 'True Neg']
categories = ['Ringed Seal', 'Noise']

confusion_matrix_plot(cm, output_dir, group_names=labels, categories=categories, cmap='viridis')
# Out:
# Confusion Matrix
