# %% [markdown]
# # Plot Spectrograms

# %%
import pandas as pd
import seaborn as sns
pd.options.mode.chained_assignment = None
import sys
import matplotlib.pyplot as plt
from ketos.data_handling import selection_table as sl
from ketos.audio.spectrogram import MagSpectrogram
from ketos.audio.audio_loader import AudioLoader, SelectionTableIterator
import os
import glob
import json

# %%
def load_audio_seg(annot_file, spec_file, data_dir):
    """
    Plot spectrograms for review
    :param annot_file: annotation file (xlsx)
    :param spec_file: spectrogram file
    :param data_dir: directory where data is stored (main level)
    :return:
    """

    annot = pd.read_csv(annot_file)

    # something up with loading in the spectro file
    f = open(spec_file)
    spec_info = json.load(f)
    rep = spec_info['spectrogram']

    # need to drop units
    #for val in rep:
    #    rep[val] = rep[val].split(' ')[0]

    # specify the audio representation
    #rep = {'window': 0.05, 'step': 0.001, 'window_func': 'hamming', 'freq_min': 100, 'freq_max': 1200,
    #       'type': 'MagSpectrogram', 'duration': 5.0}

    # step: 50%: 0.025

    # deal with merging of cells in the annotations table
    for ii in range(0, len(annot)):
        if type(annot.loc[ii][0]) == str:
            filename = annot.loc[ii][0]
        else:
            filename = annot['filename'][ii]

    # standardize tables
    annot = annot.ffill()
    annot_std = sl.standardize(table=annot)
    print('table standardized? ' + str(sl.is_standardized(annot_std)))

    # define spectrogram generation parameters
    spec_par = sl.select(annotations=annot_std, length=3.0, step=1, min_overlap=1, center=False)

    # create a generator for iterating over all the selections
    generator = SelectionTableIterator(data_dir=data_dir, selection_table=spec_par)

    # Create a loader by passing the generator and the representation to the AudioLoader
    loader = AudioLoader(selection_gen=generator, representation=MagSpectrogram, representation_params=rep, pad=False)

    # print number of segments
    print('Total number of segments is ' + str(loader.num()))
    annots = float(loader.num())

    return annots, loader


def plot_spectrogram(annot, loader, output_dir):
    """
    Plots spectrograms from an audioLoader item, call load_audio_seg first, less options than the old function
    but more useful (?)
    :param annot: annotation table returned from load_audio_seg
    :param loader: audioloader returned from load_audio_seg
    :param output_dir: output path to where you want the image saved
    :return:
    """

    #for ii in range(0, int(annot)):
    for ii in range(0, 200):    
        spec = next(loader)
        print('plotting annot #' + str(ii))
        spec.plot()
        fig = spec.plot()
        path = output_dir
        figname = path + "\\" + str(ii) + '.png'
        #plt.title(str(spec.label) + ', annot #' + str(ii), y=-0.01)
        #plt.tight_layout()
        fig.savefig(figname)
        #fig.show()
        #plt.close(fig)

# %%
### Plot Spectrograms ###
#annot_file = r'E:\final-baseline-detector\annots\pos\ULU2022_all_formatted_1sec.csv'
annot_file = r'E:\baseline-with-normalization-reduce-tonal\fine-tuning\CierrasFiles\formatted\test.csv'
data_dir = r"D:\ringed-seal-data"
output_dir = r'E:\baseline-with-normalization-reduce-tonal\fine-tuning\CierrasFiles\plots'
spec_file = r'E:\baseline-with-normalization-reduce-tonal\spec_config_100-1200Hz-0.032-hamm-normalized-reduce-tonal.json'

# create an audioloader with the spectrograms
# note you need to define step, maximum overlap, and length in this step
annot, loader = load_audio_seg(annot_file, spec_file, data_dir)

# take audio segments and create spectrogram representation
plot_spectrogram(annot, loader, output_dir)
# Out:
# FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# table standardized? True
# Total number of segments is 598
# plotting annot #0
# RuntimeWarning: Waveform padded with its own reflection to achieve required length to compute the stft. 1403 samples were padded on the left and 0 samples were padded on the right
# RuntimeWarning: Waveform padded with its own reflection to achieve required length to compute the stft. 189 samples were padded on the left and 0 samples were padded on the right
# plotting annot #1
# plotting annot #2
# plotting annot #3
# plotting annot #4
# plotting annot #5
# plotting annot #6
# plotting annot #7
# plotting annot #8
# plotting annot #9
# plotting annot #10
# plotting annot #11
# RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# plotting annot #12
# plotting annot #13
# plotting annot #14
# plotting annot #15
# plotting annot #16
# plotting annot #17
# plotting annot #18
# plotting annot #19
# plotting annot #20
# plotting annot #21
# plotting annot #22
# plotting annot #23
# plotting annot #24
# plotting annot #25
# plotting annot #26
# plotting annot #27
# plotting annot #28
# plotting annot #29
# plotting annot #30
# plotting annot #31
# plotting annot #32
# plotting annot #33
# plotting annot #34
# plotting annot #35
# plotting annot #36
# plotting annot #37
# plotting annot #38
# plotting annot #39
# plotting annot #40
# plotting annot #41
# plotting annot #42
# plotting annot #43
# plotting annot #44
# plotting annot #45
# plotting annot #46
# plotting annot #47
# plotting annot #48
# plotting annot #49
# plotting annot #50
# plotting annot #51
# plotting annot #52
# plotting annot #53
# plotting annot #54
# plotting annot #55
# plotting annot #56
# plotting annot #57
# plotting annot #58
# plotting annot #59
# plotting annot #60
# plotting annot #61
# plotting annot #62
# plotting annot #63
# plotting annot #64
# plotting annot #65
# plotting annot #66
# plotting annot #67
# plotting annot #68
# plotting annot #69
# plotting annot #70
# plotting annot #71
# plotting annot #72
# plotting annot #73
# plotting annot #74
# plotting annot #75
# plotting annot #76
# plotting annot #77
# plotting annot #78
# plotting annot #79
# plotting annot #80
# plotting annot #81
# plotting annot #82
# plotting annot #83
# plotting annot #84
# plotting annot #85
# plotting annot #86
# plotting annot #87
# plotting annot #88
# plotting annot #89
# plotting annot #90
# plotting annot #91
# plotting annot #92
# plotting annot #93
# plotting annot #94
# plotting annot #95
# plotting annot #96
# plotting annot #97
# plotting annot #98
# plotting annot #99
# plotting annot #100
# plotting annot #101
# plotting annot #102
# plotting annot #103
# plotting annot #104
# plotting annot #105
# plotting annot #106
# plotting annot #107
# plotting annot #108
# plotting annot #109
# plotting annot #110
# plotting annot #111
# plotting annot #112
# plotting annot #113
# plotting annot #114
# plotting annot #115
# plotting annot #116
# plotting annot #117
# plotting annot #118
# plotting annot #119
# plotting annot #120
# plotting annot #121
# plotting annot #122
# plotting annot #123
# plotting annot #124
# plotting annot #125
# plotting annot #126
# plotting annot #127
# plotting annot #128
# plotting annot #129
# plotting annot #130
# plotting annot #131
# plotting annot #132
# plotting annot #133
# plotting annot #134
# plotting annot #135
# plotting annot #136
# plotting annot #137
# plotting annot #138
# plotting annot #139
# plotting annot #140
# plotting annot #141
# plotting annot #142
# plotting annot #143
# plotting annot #144
# plotting annot #145
# plotting annot #146
# plotting annot #147
# plotting annot #148
# plotting annot #149
# plotting annot #150
# plotting annot #151
# plotting annot #152
# plotting annot #153
# plotting annot #154
# plotting annot #155
# plotting annot #156
# plotting annot #157
# plotting annot #158
# plotting annot #159
# plotting annot #160
# plotting annot #161
# plotting annot #162
# plotting annot #163
# plotting annot #164
# plotting annot #165
# plotting annot #166
# plotting annot #167
# plotting annot #168
# plotting annot #169
# plotting annot #170
# plotting annot #171
# plotting annot #172
# plotting annot #173
# plotting annot #174
# plotting annot #175
# plotting annot #176
# plotting annot #177
# plotting annot #178
# plotting annot #179
# plotting annot #180
# plotting annot #181
# plotting annot #182
# plotting annot #183
# plotting annot #184
# plotting annot #185
# plotting annot #186
# plotting annot #187
# plotting annot #188
# plotting annot #189
# plotting annot #190
# plotting annot #191
# plotting annot #192
# plotting annot #193
# plotting annot #194
# plotting annot #195
# plotting annot #196
# plotting annot #197
# plotting annot #198
# plotting annot #199
# Error in callback <function _draw_all_if_interactive at 0x000002EAFBF44CA0> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x000002EAB5EBA550> (for post_execute):
# KeyboardInterrupt
